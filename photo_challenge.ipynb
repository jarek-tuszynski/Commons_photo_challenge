# %% [markdown]
# # Wikimedia Commons Photo Challenge tools

# %%
import photo_challenge_library as pcl
submit_page1 = 'Commons:Photo challenge/Submitting'
submit_page2 = 'Commons:Photo challenge/Submitting_old'
vote_page1 = 'Commons:Photo challenge/Voting'
vote_page2 = 'Commons:Photo challenge/Voting_old'

# %% [markdown]
# ## Archive

# %% [markdown]
# #### Archive [Commons:Photo challenge/Submitting](https://commons.wikimedia.org/wiki/Commons:Photo_challenge/Submitting) page
# by copying to [Commons:Photo challenge/Submitting old](https://commons.wikimedia.org/wiki/Commons:Photo_challenge/Submitting_old)

# %%
pcl.copy_commons_page(source_title=submit_page1, target_title=submit_page2)
# Out:
# Page [[Commons:Photo challenge/Submitting old]] saved

# %% [markdown]
# #### Archive [Commons:Photo challenge/Voting](https://commons.wikimedia.org/wiki/Commons:Photo_challenge/Voting) page
# by copying to [Commons:Photo challenge/Voting old](https://commons.wikimedia.org/wiki/Commons:Photo_challenge/Voting_old)

# %%
pcl.copy_commons_page(source_title=vote_page1, target_title=vote_page2)
# Out:
# Page [[Commons:Photo challenge/Voting old]] saved

# %% [markdown]
# ## Create voting pages

# %% [markdown]
# #### Extract names of last month challenges
# from [Commons:Photo challenge/Submitting old](https://commons.wikimedia.org/wiki/Commons:Photo_challenge/Submitting_old)

# %%
challenge_list = pcl.get_submitted_challenges(submit_page2)
print(challenge_list)
# Out:
# ['2026 - January - Brutalist architecture', '2026 - January - Peace']

# %% [markdown]
# #### Create new text of voting index
# to be copied manually to [Commons:Photo challenge/Voting](https://commons.wikimedia.org/wiki/Commons:Photo_challenge/Voting)

# %%
pcl.get_new_text_of_voting_index(challenge_list)
# Out:
# === {{ucfirst:{{ISOdate|2026-01|{{PAGELANGUAGE}}}}}} ===
# * [[Commons:Photo challenge/2026 - January - Brutalist architecture/Voting|2026 – {{ucfirst:{{I18n month|January}}}} – {{Label|Q994776|capitalization=ucfirst|link=-}}]]
# * [[Commons:Photo challenge/2026 - January - Peace/Voting|2026 – {{ucfirst:{{I18n month|January}}}} – {{Label|Q454|capitalization=ucfirst|link=-}}]]

# %% [markdown]
# #### Create first voting page

# %%
file_df = pcl.create_voting_page_from_submission_page(challenge_list[0])
# Out:
# create voting page
# min_upload_date 2026-01-01 00:00:00
# max_upload_date 2026-02-01 12:00:00
# close_time 2026-01-31 12:00:00
# vote_close_time 2026-03-01 12:00:00
# Issues:
# * REMOVED: [[:File:Building in Winnipeg's Exchange District.jpg]] by [[User:McCIrishman|McCIrishman]], since the user uploded more than allowed 4 entries.
#
# * REMOVED: [[:File:Bank building in Winnipeg.jpg]] by [[User:McCIrishman|McCIrishman]], since the user uploded more than allowed 4 entries.
#
# * REMOVED: [[:File:300 Main under construction.jpg]] by [[User:McCIrishman|McCIrishman]], since the user uploded more than allowed 4 entries.
#
# * REMOVED: [[:File:Fort Gary Apartments in Winnipeg.jpg]] by [[User:McCIrishman|McCIrishman]], since the user uploded more than allowed 4 entries.
#
# * REMOVED: [[:File:Ceiling of the Basilica of the Madonna delle Lacrime, Centered.jpg]] by [[User:Julian Lupyan|Julian Lupyan]] was uploaded 2025-09-23 22:50:03 before the challenge opened 2026-01-01 00:00:00.
#
# * REMOVED: [[:File:Ceiling of the Basilica of the Madonna delle Lacrime.jpg]] by [[User:Julian Lupyan|Julian Lupyan]] was uploaded 2025-09-23 22:50:07 before the challenge opened 2026-01-01 00:00:00.

# %% [markdown]
# #### Create second voting page

# %%
file_df = pcl.create_voting_page_from_submission_page(challenge_list[1])
# Out:
# create voting page
# min_upload_date 2026-01-01 00:00:00
# max_upload_date 2026-02-01 12:00:00
# close_time 2026-01-31 12:00:00
# vote_close_time 2026-03-01 12:00:00
# Issues:
# * REMOVED: [[:File:Peace mural in Derry Northern Ireland.jpg]] by [[User:McCIrishman|McCIrishman]], since the user uploded more than allowed 4 entries.
#
# * REMOVED: [[:File:Discarded peace protest signs.jpg]] by [[User:McCIrishman|McCIrishman]], since the user uploded more than allowed 4 entries.
#
# * REMOVED: [[:File:Civil Rights Mural in Derry Northern Ireland.jpg]] by [[User:McCIrishman|McCIrishman]], since the user uploded more than allowed 4 entries.

# %% [markdown]
# ## Evaluate voting pages

# %% [markdown]
# ### Extract names of last month challenges
# From [Commons:Photo challenge/Voting old](https://commons.wikimedia.org/wiki/Commons:Photo_challenge/Voting_old)

# %%
header, challenge_list = pcl.get_voting_challenges(vote_page2)
print(challenge_list)
idx = 0
# Out:
# ['2025 - November - Parking', '2025 - November - Glaciers']

# %% [markdown]
# ### Process first challenge

# %%
idx = 1

# %% [markdown]
# ### Process challenge

# %%
pcl.process_challenge(challenge_list[idx])
# Out:
# validate_votes 1 254 67
# validate_votes 2 67 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 pcl.process_challenge(challenge_list[i])
#
# File ~/photo_challenge_library.py:701, in process_challenge(challenge)
#     699 # revise voting page and create result page
#     700 revise_voting_page(wiki_text, revised_file)
# --> 701 create_winners_page(file_df, winners_file, challenge)
#     703 # create result page
#     704 n_voter = vote_df['voter'].nunique()
#
# File ~/photo_challenge_library.py:574, in create_winners_page(file_df, file_name, challenge)
#     572 fp.write( "|height   = {{{height|240}}}\n");
#     573 for i in range(3):
# --> 574     title = add_line_breaks(file_df.iloc[i]["title"], 40)
#     575     fp.write("|image_{}  = {}\n".format(i+1, file_df.iloc[i]["file_name"]))
#     576     fp.write("|title_{}  = {}\n".format(i+1, title))
#
# File /srv/paws/lib/python3.12/site-packages/pandas/core/indexing.py:1192, in _LocationIndexer.__getitem__(self, key)
#    1190 maybe_callable = com.apply_if_callable(key, self.obj)
#    1191 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1192 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /srv/paws/lib/python3.12/site-packages/pandas/core/indexing.py:1753, in _iLocIndexer._getitem_axis(self, key, axis)
#    1750     raise TypeError("Cannot index by location index with a non-integer key")
#    1752 # validate the location
# -> 1753 self._validate_integer(key, axis)
#    1755 return self.obj._ixs(key, axis=axis)
#
# File /srv/paws/lib/python3.12/site-packages/pandas/core/indexing.py:1686, in _iLocIndexer._validate_integer(self, key, axis)
#    1684 len_axis = len(self.obj._get_axis(axis))
#    1685 if key >= len_axis or key < -len_axis:
# -> 1686     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# ### Save result page

# %%
pcl.create_commons_page(challenge_list[i], 'result', 'Voting/Result')
# Out:
# Created [Commons:Photo_challenge/2025_-_October_-_Dyeing/Result](https://commons.wikimedia.org/wiki/Commons:Photo_challenge/2025_-_October_-_Dyeing/Result
# Page [[Commons:Photo challenge/2025 - October - Dyeing/Result]] saved

# %% [raw]
# ### Save other pages

# %%
pcl.create_commons_page(challenge_list[i], 'winners', 'Winners')
# Out:
# Created [Commons:Photo_challenge/2025_-_October_-_Dyeing/Winners](https://commons.wikimedia.org/wiki/Commons:Photo_challenge/2025_-_October_-_Dyeing/Winners
# Page [[Commons:Photo challenge/2025 - October - Dyeing/Winners]] saved

# %%
print(challenge_list[i])
pcl.talk_to_winners(challenge_list[i])
# Out:
# 2025 - October - Dyeing
# Page [[User talk:Wowan1978]] saved
# Page [[User talk:Wowan1978]] saved
# Page [[User talk:Pedemann]] saved
# Page [[Commons talk:Photo challenge]] saved

# %% [markdown]
# ### Debuging

# %%
file_df, vote_df = pcl.parse_voting_page1(challenge_list[0])
file_df.to_csv("test_files.csv", index=False)
vote_df.to_csv("test_votes.csv", index=False)
